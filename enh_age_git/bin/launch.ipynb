# %%
import os
import sys, traceback
import argparse
import datetime
import glob
from functools import reduce
from itertools import groupby
from functools import partial
from multiprocessing import Pool
from pybedtools import BedTool
from pybedtools.helpers import BEDToolsError, cleanup, get_tempdir, set_tempdir
import subprocess

print("last run", datetime.datetime.now())

def sbatch_age_sequence(file, run_any, iterations, run_age, run_break, run_tfbs, run_shuffle, run_testbed):
    cmd = "sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm %s %s %s %s %s %s %s" \
    % (file, iterations, run_age, run_break, run_tfbs, run_shuffle, run_testbed)
        
    print("SLURM", file, datetime.datetime.now())
    print(cmd)
    if run_any ==1:
        subprocess.call(cmd, shell=True)
        
def python_age_sequence(file, run_any, iterations, run_age, run_break, run_tfbs, run_shuffle, run_testbed):
    cmd = '''python /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.py %s -i %s -a %s -b %s -t %s -sh %s -rt %s'''\
    % (file, iterations, run_age, run_break, run_tfbs, run_shuffle, run_testbed)
    print(cmd)
# Out:
# last run 2020-07-10 01:06:31.083499

# %% [markdown]
# # launch FANTOM w/ python in cmd line

# %%
os.chdir("/dors/capra_lab/users/fongsl/enh_age/bin/")
source_path = "/dors/capra_lab/projects/enhancer_ages/fantom/data/"

samples = glob.glob("%sall_fantom_enh.bed"%source_path)

sample_dict = {}

ITERATIONS = 0
AGE_VAL = 1
BREAK_VAL = 1
TFBS_VAL = 0
SHUF_VAL = 0
RUN_BED = 1

RUN = 1 # Launch command or dont
SBATCH =  # Sbatch or run w/ python interpreter
val = 0
for sample in samples:
    sample_id = (sample.split("/")[-1]).split(".")[0]
    sample_dict[sample_id] = sample

print("start", datetime.datetime.now())

for sample_id, file in sample_dict.items():

    if SBATCH ==1:
         sbatch_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
    else:
        
        python_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
 

    val +=1

print("end", datetime.datetime.now())
# Out:
# start 2020-02-20 14:59:33.332736
# PYTHON /dors/capra_lab/projects/enhancer_ages/fantom/data/all_fantom_enh.bed 2020-02-20 14:59:33.333193
# python /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.py /dors/capra_lab/projects/enhancer_ages/fantom/data/all_fantom_enh.bed -i 0 -a 1 -b 1 -t 0 -sh 0 -rt 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-5e7bb0fa1b84> in <module>
#      28     else:
#      29
# ---> 30         python_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
#      31
#      32
#
# <ipython-input-8-f7b2ed0a2a7d> in python_age_sequence(file, run_any, iterations, run_age, run_break, run_tfbs, run_shuffle, run_testbed)
#      20         sequence = ["python", py, file, "-i", str(iterations), "-a", str(run_age), "-b", str(run_break),\
#      21                     "-t", str(run_tfbs), "-sh", str(run_shuffle), "-rt", str(run_testbed)]
# ---> 22         result= subprocess.run(" ".join(sequence), stdout=subprocess.PIPE, input=input)
#      23         #result = subprocess.run(cmd, stdout=subprocess.PIPE, input=input)
#      24         print(result.stdout.decode('utf-8'))
#
# /dors/capra_lab/users/fongsl/sfenv/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     421         kwargs['stdin'] = PIPE
#     422
# --> 423     with Popen(*popenargs, **kwargs) as process:
#     424         try:
#     425             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /dors/capra_lab/users/fongsl/sfenv/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     727                                 c2pread, c2pwrite,
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#     731             # Cleanup if the child failed starting.
#
# /dors/capra_lab/users/fongsl/sfenv/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1362                         if errno_num == errno.ENOENT:
#    1363                             err_msg += ': ' + repr(err_filename)
# -> 1364                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1365                 raise child_exception_type(err_msg)
#    1366
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.py /dors/capra_lab/projects/enhancer_ages/fantom/data/all_fantom_enh.bed -i 0 -a 1 -b 1 -t 0 -sh 0 -rt 1': 'python /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.py /dors/capra_lab/projects/enhancer_ages/fantom/data/all_fantom_enh.bed -i 0 -a 1 -b 1 -t 0 -sh 0 -rt 1'

# %% [markdown]
# # launch ROADMAP w/ python in cmd line

# %%
os.chdir("/dors/capra_lab/users/fongsl/enh_age/bin/")
source_path = "/dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/"
#samples = glob.glob("%sHsap_H3K27ac_plus_H3K4me3_minus_E003.bed"%source_path)
samples = glob.glob("%s*.bed"%source_path)
sample_dict = {}

ITERATIONS = 0
AGE_VAL = 1
BREAK_VAL = 1
TFBS_VAL = 0
SHUF_VAL = 0
RUN_BED = 1

RUN = 1 # Launch command or dont
SBATCH = 1 # Sbatch or run w/ python interpreter

for sample in samples:
    sample_id = (sample.split("/")[-1]).split(".")[0]
    sample_dict[sample_id] = sample

print("start", datetime.datetime.now())
val = 0
for sample_id, file in sample_dict.items():
    sid = sample_id.split("_")[-1]

    print(sid, val)

    if SBATCH ==1:
         sbatch_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
    else:
        python_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
        print(sample_id)
    val +=1
print("end", datetime.datetime.now())

# %% [markdown]
# # trimmed_shuffle ROADMAP

# %%
os.chdir("/dors/capra_lab/users/fongsl/enh_age/bin/")
source_path = "/dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/"
#samples = glob.glob("%sHsap_H3K27ac_plus_H3K4me3_minus_E003.bed"%source_path)
samples = glob.glob("%sshuf-trimmed-310*.bed"%source_path)
sample_dict = {}

ITERATIONS = 0
AGE_VAL = 1
BREAK_VAL = 1
TFBS_VAL = 0
SHUF_VAL = 0
RUN_BED = 1

RUN = 1 # Launch command or dont
SBATCH = 1 # Sbatch or run w/ python interpreter

for sample in samples[1:]:
    sample_id = (sample.split("/")[-1]).split(".")[0]
    sample_dict[sample_id] = sample

print("start", datetime.datetime.now())
val = 0
for sample_id, file in sample_dict.items():
    sid = sample_id.split("_")[-1]

    print(sid, val)

    if SBATCH ==1:
         sbatch_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
    else:
        python_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
        print(sample_id)
    val +=1

print("end", datetime.datetime.now())
# Out:
# start 2020-07-10 01:30:08.582497
# E122 0
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E122.bed 2020-07-10 01:30:08.583663
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E122.bed 0 1 1 0 0 1
# E038 1
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E038.bed 2020-07-10 01:30:08.637936
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E038.bed 0 1 1 0 0 1
# E063 2
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E063.bed 2020-07-10 01:30:08.753467
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E063.bed 0 1 1 0 0 1
# E124 3
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E124.bed 2020-07-10 01:30:08.788020
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E124.bed 0 1 1 0 0 1
# E113 4
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E113.bed 2020-07-10 01:30:09.094669
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E113.bed 0 1 1 0 0 1
# E089 5
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E089.bed 2020-07-10 01:30:09.181835
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E089.bed 0 1 1 0 0 1
# E101 6
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E101.bed 2020-07-10 01:30:09.223487
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E101.bed 0 1 1 0 0 1
# E103 7
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E103.bed 2020-07-10 01:30:09.252614
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E103.bed 0 1 1 0 0 1
# E068 8
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E068.bed 2020-07-10 01:30:09.407798
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E068.bed 0 1 1 0 0 1
# E059 9
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E059.bed 2020-07-10 01:30:09.438069
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E059.bed 0 1 1 0 0 1
# E069 10
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E069.bed 2020-07-10 01:30:09.603821
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E069.bed 0 1 1 0 0 1
# E032 11
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E032.bed 2020-07-10 01:30:09.674500
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E032.bed 0 1 1 0 0 1
# E022 12
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E022.bed 2020-07-10 01:30:09.886613
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E022.bed 0 1 1 0 0 1
# E041 13
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E041.bed 2020-07-10 01:30:09.928721
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E041.bed 0 1 1 0 0 1
# E012 14
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E012.bed 2020-07-10 01:30:10.002049
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E012.bed 0 1 1 0 0 1
# E061 15
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E061.bed 2020-07-10 01:30:10.102723
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E061.bed 0 1 1 0 0 1
# E017 16
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E017.bed 2020-07-10 01:30:10.241807
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E017.bed 0 1 1 0 0 1
# E084 17
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E084.bed 2020-07-10 01:30:10.278538
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E084.bed 0 1 1 0 0 1
# E090 18
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E090.bed 2020-07-10 01:30:10.352806
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E090.bed 0 1 1 0 0 1
# E115 19
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E115.bed 2020-07-10 01:30:10.650585
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E115.bed 0 1 1 0 0 1
# E123 20
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E123.bed 2020-07-10 01:30:10.687199
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E123.bed 0 1 1 0 0 1
# E085 21
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E085.bed 2020-07-10 01:30:10.829962
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E085.bed 0 1 1 0 0 1
# E042 22
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E042.bed 2020-07-10 01:30:10.875525
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E042.bed 0 1 1 0 0 1
# E008 23
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E008.bed 2020-07-10 01:30:10.912040
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E008.bed 0 1 1 0 0 1
# E045 24
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E045.bed 2020-07-10 01:30:11.066209
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E045.bed 0 1 1 0 0 1
# E079 25
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E079.bed 2020-07-10 01:30:11.186707
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E079.bed 0 1 1 0 0 1
# E091 26
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E091.bed 2020-07-10 01:30:11.331021
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E091.bed 0 1 1 0 0 1
# E108 27
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E108.bed 2020-07-10 01:30:11.378926
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E108.bed 0 1 1 0 0 1
# E120 28
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E120.bed 2020-07-10 01:30:11.412506
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E120.bed 0 1 1 0 0 1
# E105 29
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E105.bed 2020-07-10 01:30:11.548722
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E105.bed 0 1 1 0 0 1
# E019 30
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E019.bed 2020-07-10 01:30:11.617494
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E019.bed 0 1 1 0 0 1
# E029 31
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E029.bed 2020-07-10 01:30:11.653019
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E029.bed 0 1 1 0 0 1
# E049 32
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E049.bed 2020-07-10 01:30:11.691358
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E049.bed 0 1 1 0 0 1
# E039 33
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E039.bed 2020-07-10 01:30:11.806324
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E039.bed 0 1 1 0 0 1
# E046 34
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E046.bed 2020-07-10 01:30:11.911597
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E046.bed 0 1 1 0 0 1
# E094 35
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E094.bed 2020-07-10 01:30:11.942394
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E094.bed 0 1 1 0 0 1
# E050 36
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E050.bed 2020-07-10 01:30:11.979922
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E050.bed 0 1 1 0 0 1
# E065 37
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E065.bed 2020-07-10 01:30:12.009315
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E065.bed 0 1 1 0 0 1
# E092 38
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E092.bed 2020-07-10 01:30:12.192445
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E092.bed 0 1 1 0 0 1
# E034 39
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E034.bed 2020-07-10 01:30:12.247992
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E034.bed 0 1 1 0 0 1
# E071 40
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E071.bed 2020-07-10 01:30:12.292605
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E071.bed 0 1 1 0 0 1
# E062 41
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E062.bed 2020-07-10 01:30:12.556912
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E062.bed 0 1 1 0 0 1
# E066 42
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E066.bed 2020-07-10 01:30:12.592086
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E066.bed 0 1 1 0 0 1
# E040 43
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E040.bed 2020-07-10 01:30:12.640718
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E040.bed 0 1 1 0 0 1
# E118 44
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E118.bed 2020-07-10 01:30:12.676307
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E118.bed 0 1 1 0 0 1
# E096 45
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E096.bed 2020-07-10 01:30:12.825100
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E096.bed 0 1 1 0 0 1
# E074 46
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E074.bed 2020-07-10 01:30:12.980124
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E074.bed 0 1 1 0 0 1
# E048 47
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E048.bed 2020-07-10 01:30:13.034069
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E048.bed 0 1 1 0 0 1
# E126 48
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E126.bed 2020-07-10 01:30:13.210691
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E126.bed 0 1 1 0 0 1
# E127 49
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E127.bed 2020-07-10 01:30:13.269153
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E127.bed 0 1 1 0 0 1
# E047 50
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E047.bed 2020-07-10 01:30:13.384169
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E047.bed 0 1 1 0 0 1
# E056 51
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E056.bed 2020-07-10 01:30:13.418688
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E056.bed 0 1 1 0 0 1
# E037 52
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E037.bed 2020-07-10 01:30:13.456487
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E037.bed 0 1 1 0 0 1
# E100 53
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E100.bed 2020-07-10 01:30:13.494724
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E100.bed 0 1 1 0 0 1
# E026 54
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E026.bed 2020-07-10 01:30:13.714105
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E026.bed 0 1 1 0 0 1
# E076 55
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E076.bed 2020-07-10 01:30:13.858154
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E076.bed 0 1 1 0 0 1
# E097 56
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E097.bed 2020-07-10 01:30:13.922079
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E097.bed 0 1 1 0 0 1
# E011 57
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E011.bed 2020-07-10 01:30:13.987988
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E011.bed 0 1 1 0 0 1
# E005 58
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E005.bed 2020-07-10 01:30:14.028320
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E005.bed 0 1 1 0 0 1
# E015 59
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E015.bed 2020-07-10 01:30:14.193644
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E015.bed 0 1 1 0 0 1
# E128 60
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E128.bed 2020-07-10 01:30:14.447254
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E128.bed 0 1 1 0 0 1
# E067 61
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E067.bed 2020-07-10 01:30:14.490498
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E067.bed 0 1 1 0 0 1
# E095 62
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E095.bed 2020-07-10 01:30:14.530028
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E095.bed 0 1 1 0 0 1
# E014 63
# SLURM /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E014.bed 2020-07-10 01:30:14.563495
# sbatch /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.slurm /dors/capra_lab/projects/enhancer_ages/roadmap_encode/data/hg19_roadmap_samples_enh_age/download/h3k27ac_plus_h3k4me3_minus_peaks/trimmed/shuffle/shuf-trimmed-310_E014.bed 0 1 1 0 0 1
# end 2020-07-10 01:30:14.705218

# %% [markdown]
# # launch Ernst MPRA w/ python in cmd line

# %%
########################
# get MPRA enhancers
########################
enh_path ="/dors/capra_lab/data/mpra/ernst16/"

os.chdir(enh_path)
samples = glob.glob("%s**/tiles_*_ScaleUpDesign1and2_combinedP.bed" % enh_path, recursive = True)

sample_dict = {}
for sample in samples:
    sample_id = (sample.split("/")[-1]).split("_")[1]
    sample_dict[sample_id] = sample

print("start", datetime.datetime.now())
for sample_id, file in sample_dict.items():
    cmd = "python /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.py %s %s" % (file, sample_id)
    print(sample_id, datetime.datetime.now())
    os.system(cmd)  
print("end", datetime.datetime.now())

# %% [markdown]
# # launch Klein MPRA w/ python in cmd line

# %%
enh_path ="/dors/capra_lab/projects/enhancer_ages/klein2018/data/"
samples = glob.glob("%smerged.bed"%enh_path) # published and not published enhancers tiles merged together

# %%
enh_path ="/dors/capra_lab/projects/enhancer_ages/klein2018/data/"
samples = glob.glob("%smerged.bed"%enh_path) # published and not published enhancers tiles merged together
samples = glob.glob("%sklein_tile_activity.bed" % enh_path)
print("start", datetime.datetime.now())

ITERATIONS = 100
AGE_VAL = 1
BREAK_VAL = 1
TFBS_VAL = 1
SHUF_VAL = 1
RUN_BED = 0

RUN = 1 # Launch command or dont
SBATCH = 0 # Sbatch or run w/ python interpreter

val = 0
sample_dict={}
for sample in samples:
    sample_id = (sample.split("/")[-1]).split(".")[0]
    sample_dict[sample_id] = sample



for sample_id, file in sample_dict.items():

    if SBATCH ==1:
         sbatch_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
    else:
        python_age_sequence(file, RUN, ITERATIONS, AGE_VAL, BREAK_VAL, TFBS_VAL, SHUF_VAL, RUN_BED)
        
        
        #%run '/dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.py'\
        #$file '-i' $ITERATIONS "-a" $AGE_VAL "-b" $BREAK_VAL "-t" $TFBS_VAL "-sh" $SHUF_VAL
 
    val +=1
# Out:
# start 2020-03-13 13:48:19.195729
# python /dors/capra_lab/users/fongsl/enh_age/bin/age_enhancers.py /dors/capra_lab/projects/enhancer_ages/klein2018/data/klein_tile_activity.bed -i 100 -a 1 -b 1 -t 1 -sh 1 -rt 0

# %% [markdown]
# # launch villar

# %%
########################
# get MPRA enhancers
########################
enh_path ="/dors/capra_lab/projects/enhancer_ages/villar15/Hsap/"

os.chdir(enh_path)
file = enh_path ="/dors/capra_lab/projects/enhancer_ages/villar15/data/HSap_H3K4me3.H3K27Ac_overlap_H3K27Aconly.bed"

# %% [markdown]
# # fimo fantom

# %%
source_path = "/dors/capra_lab/projects/enhancer_ages/fantom/data/download/"
samples = glob.glob("%s*enhancers.bed"%source_path)
sample_dict = {}

RUN = 0 # Launch command?
SBATCH = 1 # Sbatch or run w/ python interpreter

for sample in samples:
    sample_id = ''.join(((sample.split("/")[-1]).split(".")[0]).split("_")[:2])
    sample_dict[sample_id] = sample

for sample_id, file in sample_dict.items():
    if SBATCH ==1:
        cmd = "sbatch /dors/capra_lab/users/fongsl/enh_age/bin/fimo_tfbs.slurm %s %s"\
        % (file, sample_id)
        
        print("SLURM", sample_id, datetime.datetime.now())
        print(cmd)
        if RUN ==1:
            os.system(cmd)
    else:
        cmd = "python /dors/capra_lab/users/fongsl/enh_age/bin/fimo_tfbs.py %s %s" \
        % (file, sample_id)
        
        print("PYTHON", sample_id, datetime.datetime.now())
        print(cmd)
        if RUN ==1:
            os.system(cmd)
    break

# %%
import glob
import matplotlib.pyplot as plt

from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors


import numpy as np
import os, sys
import pandas as pd
from scipy import stats
import seaborn as sns
import statsmodels
import statsmodels.api as sm
import subprocess

sys.path.append("/dors/capra_lab/users/fongsl/tools/py_")
import config_readwrite as crw

name = "/dors/capra_lab/users/fongsl/enh_ages/core_v_derived/config_landscape"
config, configfilename = crw.read_config(name)

ENHBASE = config["ENCODE"]["path_cCRE"]
#ENHBASE = "/dors/capra_lab/projects/enhancer_ages/encode/hepg2/data/"

ENCODEPATH = config["ENCODE"]["path_tf"]

RE = config["ENCODE_HepG2_TFBS"]["results"]
RE_DATA =  config["ENCODE_HepG2_TFBS"]["results_data"]


if os.path.exists(RE_DATA) == False:
    os.mkdir(RE_DATA)

colors = ["amber", "dusty purple", "windows blue"]
PAL = sns.xkcd_palette(colors)
sns.palplot(PAL)

colors = ["windows blue"]
DERPAL = sns.xkcd_palette(colors)
sns.palplot(DERPAL)

# %% [markdown]
# # Functions

# %%
def get_cell_lines():
    sample_dict = {
        "HepG2": "ELS_combined_HepG2",
    }
    return sample_dict


def get_paths(cell_line, file_tag, fantombase, encodepath):

    FANTOMPATH = os.path.join(fantombase, file_tag, "ages")
    FANTOM = os.path.join(FANTOMPATH, f"{file_tag}syn_breaks_%s_ages.bed")

    if "CL" in cell_line:
        ENCODEFILE = "cells/" + cell_line.split("_CL")[0] + ".bed.gz"
    elif cell_line == "all_fantom_enh":
        ENCODEFILE = "trimmed_encRegTfbsClusteredWithCells.bed"
    else:
        ENCODEFILE = "cells/" + cell_line + ".bed.gz"

    ENCODE = os.path.join(encodepath, ENCODEFILE)

    INTERSECTIONPATH = os.path.join(fantombase, file_tag)
    INTERSECTION = os.path.join(INTERSECTIONPATH, f"{file_tag}_x_ENCODE.bed")

    return FANTOM, ENCODE, INTERSECTION


def bed_intersect(fantom, encode, intersection):

    if os.path.exists(intersection) is False:
        cmd = f"bedtools intersect -a {fantom} -b {encode} -wao > {intersection}"

        subprocess.call(cmd, shell=True)

        print(cmd)
    else:
        print("previously done enh x encode intersection")


def get_core_age(df):
    core = df.groupby("enh_id")["mrca_2"].max().reset_index()
    core.columns = ["enh_id", 'core_mrca_2']
    df = pd.merge(df, core, how="left")

    return df


def reEval_PrimComplex(enh):

    # get all the complex enhancers w/ primate core ages
    prComEnhID = enh.loc[(enh.core == 1)
                         & (enh.core_remodeling == 1)
                         & (enh.taxon2.str.contains("Primate"))]["enh_id"].unique()

    # get all the complex enhancer ids where there is a real human derived sequence
    pr_complex = enh.loc[(enh.enh_id.isin(prComEnhID))
                         & (enh.core_remodeling == 1)
                         & (enh.core == 0)
                         & (enh.mrca == 0),
                         ]["enh_id"]

    # i'm going to reassign any primate complex enhancer
    # where derived regions are from other primates
    # get the set of primate complex enhancers w/ primate derived sequences
    # and rename them as simple enhancers
    pr_simple = set(prComEnhID) - set(pr_complex)

    # reassign core and core remodeling columns
    enh.loc[enh.enh_id.isin(pr_simple), "core"] = 1
    enh.loc[enh.enh_id.isin(pr_simple), "core_remodeling"] = 0
    return enh



def merge_syn_annot(df, core):
    # core is False, and taxon annotations will be assigned to regular syntenic blocks
    # if core is True, taxon annotations will be assigned to the core-sequence ages
    SYN_GROUP = "/dors/capra_lab/projects/enhancer_ages/hg38_syn_taxon.bed"
    syn = pd.read_csv(SYN_GROUP, sep='\t')

    # round all values
    syn[["mrca", "mrca_2"]] = syn[["mrca", "mrca_2"]].round(3)
    df["mrca"] = df["mrca"].round(3)
    
    if core is True:
        df["core_mrca_2"] = df["core_mrca_2"].round(3)
        df = pd.merge(df, syn[["mrca_2", "taxon2"]], how="left",
                  left_on="core_mrca_2", right_on="mrca_2")
    else:
        df = pd.merge(df, syn, how="left")

    return df 


def format_df(intersection_file):

    # do the dance - add mrca_2 column, get mrca_2 core age, drop mrca_2 column, then add it back, but this time to reflect the core_age and core taxon, instead of the syntenic age.

    cols = ["chr_syn", "start_syn", "end_syn",
            "enh_id", "chr", "start", "end",
            "seg_index", "core_remodeling", "core",
            "mrca",
            "chr_tf", "start_tf", "end_tf",
            "tf_id", "peak_len",
            "tf", "cell_line", "overlap"
            ]

    df = pd.read_csv(intersection_file,
                     sep='\t',
                     header=None).drop_duplicates()

    df.columns = cols  # add column names

    df = merge_syn_annot(df, False) # merge taxon information

    df["tf"] = df["tf_id"].apply(lambda x: x.split("_")[0])

    # add architecture label - core, derived, simple
    df["arch"] ="complex_core"
    df.loc[(df.core_remodeling == 0), "arch"] =  "simple"
    df.loc[df.core == 0, "arch"] = "complex_derived"

    df = reEval_PrimComplex(df)

    # add architecture label - complex, simple
    df["overallarch"] = "simple"
    df.loc[df.core_remodeling == 1, "overallarch"] = "complex"

    # add syn identifier
    df["syn_id"] = df.chr_syn + ":" + \
        df.start_syn.map(str) + "-" + df.end_syn.map(str)

    #calculate enhancer and syntenic block length
    df["enh_len"] = df.end - df.start
    df["syn_len"] = df.end_syn - df.start_syn
    df.loc[df.syn_len < 6, "syn_len"] = 0

    # binary for TF overlap, any TF that overlaps less than 6bp is not counted.
    df["tfoverlap_bin"] = 1
    df.loc[df.tf == ".", "tfoverlap_bin"] = 0
    df.loc[df.overlap < 6, "tfoverlap_bin"] = 0

    return df


def count_enhancers(df, arch, stats_f):

    if arch == "enh":
        enh_df = df.groupby(["enh_id", "core_remodeling", "overallarch"])[
                            ["mrca", "seg_index"]].max().reset_index()

        totalenh_n = enh_df.shape[0]  # 30279 enhancers total
        # 14098 simple enhancers
        simpleenh_n = enh_df.loc[enh_df.overallarch == "simple"].shape[0]
        # 8744 complex enhancers
        complexenh_n = enh_df.loc[enh_df.overallarch != "simple"].shape[0]

        p1 = f"\ntotal enh N - {totalenh_n}"
        p2 = f"\nsimple enh N - {simpleenh_n}"
        p3 = f"\ncomplex enhancer N - {complexenh_n}\n"
        info = p1 + p2 + p3
        
    elif arch == "syn":

        total = df.shape[0]
        core_n = df.loc[df.arch == "complex_core"]["syn_id"].count()
        derived_n = df.loc[df.arch == "complex_derived"]["syn_id"].count()
        simple_n = df.loc[df.arch == "simple"]["syn_id"].count()

        p1 = f"\ntotal syn N - {total}"
        p2 = f"\nsimple syn N - {simple_n}"
        p3 = f"\ncomplex core N - {core_n}"
        p4 = f"\ncomplex derived N - {derived_n}\n"
        info = p1 + p2 + p3 + p4

    with open(stats_f, "a") as write_f:
        write_f.write(info)


def mwu(tf_density, arch, kw, stats_f):

    # calculate means
    median = (tf_density.groupby("arch")["tf_density"].median()).reset_index()
    print("\narchitecture medians", median)

    if arch == "enh":

        #stratify dataframe by simple and complex arch
        simple_tfden = tf_density.loc[tf_density.arch
                                      == "simple", "tf_density"]
        complex_tfden = tf_density.loc[tf_density.arch
                                       == "complex", "tf_density"]

        # calculate MWU
        test_arch, p_arch = stats.mannwhitneyu(simple_tfden, complex_tfden)
        p1 = f"\n\n###{kw}###"
        p2 = "\nsimple v. complex enh TFBS MWU"
        p3 = f"\nstat = {round(test_arch, 3)}\np = {p_arch}\n"
        info  = p1 + p2 + p3


        listP = [p_arch]
    elif arch == "syn":

        simple_tfden = tf_density.loc[tf_density.arch\
                                      == "simple", "tf_density"]
        core_tfden = tf_density.loc[tf_density.arch\
                                    == "complex_core", "tf_density"]
        derived_tfden = tf_density.loc[tf_density.arch\
                                       == "complex_derived", "tf_density"]

        testcore, pcore = stats.mannwhitneyu(simple_tfden, core_tfden)

        test_der, p_der = stats.mannwhitneyu(derived_tfden, core_tfden)

        p1 = f"\n\n###{kw}###"
        p2 = "\nsimple v. complexcore TFBS MWU"
        p3 = f"\nstat = {round(testcore, 3)}\np = {pcore}\n"
        p4 = "\ncore v. derived MWU"
        p5 = f"\nstat = {round(test_der, 3)},\np = {p_der}\n"
        info  = p1 + p2 + p3 + p4 + p5

        listP = [pcore, p_der]

    with open(stats_f, "a") as write_f:
        write_f.write(info)
        for index, row in median.iterrows():
            write_f.write(row.to_string())
        write_f.write("\n\n")

    return listP, median

def calculate_tf_density(arch, df):

    density_cols = ["id", "len", "arch", "tfoverlap_bin", "tf_density", ]

    if arch == "enh":
        cols = ["enh_id", "enh_len", "overallarch"]
        tf_density = df.groupby(cols)["tfoverlap_bin"].sum().reset_index().drop_duplicates()

        tf_density["tf_density"] = tf_density["tfoverlap_bin"].divide(tf_density.enh_len)

    elif arch == "syn":
        cols = ["syn_id", "syn_len", "arch"]
        tf_density = df.groupby(cols)["tfoverlap_bin"].sum().reset_index()
        tf_density["tf_density"] = tf_density["tfoverlap_bin"].divide(tf_density.syn_len)

    # rename columns
    tf_density.columns = density_cols

    # how many enhancers do not overlap  TFs?
    zero_overlap = tf_density.loc[
    tf_density.tfoverlap_bin == 0].groupby("arch")[
    "id"].count().reset_index()

    return tf_density, zero_overlap


def calculate_zero_syn_freq(zero_syn, df, arch, stats_f):
    
    arch_dict = {"syn":["syn_id", "arch"],
                "enh":["enh_id", "overallarch"]}
    val= arch_dict[arch]
    
    block_id, arch_ = val[0], val[1]
    zero_syn.columns = [arch_, "zero_counts"]
    
    arch_df = df[[arch_, block_id]].drop_duplicates()

    total_arch_counts = arch_df.groupby(
        [arch_])[block_id].count().reset_index()  # counts per arch
    total_arch_counts.columns = [arch_, "total_counts"]

    zero_syn = pd.merge(zero_syn, total_arch_counts, on=arch_)
    zero_syn["freq_zero"] = zero_syn.zero_counts.divide(zero_syn.total_counts)
    zero_syn["freq_nonzero"] = 1-zero_syn["freq_zero"]

    print(zero_syn)

    with open(stats_f, "a") as write_f:
        for index, row in zero_syn.iterrows():
            write_f.write(row.to_string())
        write_f.write("\n\n")


def plot_bar_tf_density(x, y, data, outf, order, p, med):

    # plot enhancer TF density
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.set("poster")

    sns.barplot(x, y, data=data, estimator=np.median,
                order=order, palette=PAL, n_boot=10000)

    ax.set(
        xlabel="p = %s\n%s" % (p, med),
        title=outf.split("/")[-1],
        ylabel="TFBS density\nmedian"
    )

    plt.savefig(outf, bbox_inches='tight')

# %%
def prep_2x2(tf, arch1, arch2, min_instances, df, universe):

    # only evaluate enhancers that overlap TF.
    # This excludes enhancers with zero overlaps from background set.
    
    """
    Binding enrichment = TFBS-based odds that TF binds an architecture. 
        Universe is the TFs that bind architectures. 
        Interpretation: odds that a TF binds der v. core, core v. bkgd, etc.
        
    Binding enrichment != Summarized core|der-based odds that TF binds an architecture's syntenic block. 
        Universe is the summarized enhancer core and derived bound by TFs.
        Interpretation: odds that a summarized architecture is bound by TFBS is der v. core, core v. bkgd, etc.
        
        Why I don't like TFBS-based odds: counts may be biased toward multiple redundant binding sites in a single architecture. 
        Why I do like TFBS-based odds: reflects the raw odds that a TF binds an architecture among the universe of TFBS.

        FINAL DECISION: USE TFBS-BASED ODDS. EASIER TO INTERPRET. 

    # SYN-BLOCK-BASED ODDS    
    If syntenic block-based universe, use this code:


    tfdf = test.loc[test.tf == tf, ["arch", "syn_id"]].drop_duplicates().groupby("arch")["syn_id"].count().reset_index()
    bkgd = test.loc[test.tf != tf, ["arch", "syn_id"]].drop_duplicates().groupby("arch")["syn_id"].count().reset_index()


    # Summary of function below:     
    
    I want to test the enrichment of a TF binding architecture (at the syntenic block level).
    do not test how many binding sites are in an architecture. E.g. 15 TFBS in 5 derived syntenic blocks v. 5 TFBS in 5 core
    1. reduce dataframe to tf, arch, syn ids and enh_ids
    2. TF-dataframe: use groupby function to count syntenic blocks that bind TF, stratified by architecture 
    3. bkgd-dataframe: use groupby function to count syntenic blocks that bind ALL OTHER TFs, stratified by architecture
    4. prepare FET obs as the counts of syntenic blocks that bind/ do not bind TF per architecture
    """
    
    test = df[["tf", "arch", "syn_id", "enh_id"]].loc[df.tfoverlap_bin > 0].drop_duplicates()
    
    comparison_name = tf + "-" + arch1 + "_v_" + arch2 + "-" + universe
    
    if universe == 'TFBS':
        
        tfdf = test.loc[test.tf == tf, ["arch", "enh_id"]].groupby("arch")["enh_id"].count().reset_index()
        bkgd = test.loc[test.tf != tf, ["arch", "enh_id"]].groupby("arch")["enh_id"].count().reset_index()

    elif universe == "blocks":
        tfdf = test.loc[test.tf == tf, ["arch", "enh_id"]].drop_duplicates().groupby("arch")["enh_id"].count().reset_index()
        bkgd = test.loc[test.tf != tf, ["arch", "enh_id"]].drop_duplicates().groupby("arch")["enh_id"].count().reset_index()

    # incase there are nans
    blank_df = pd.DataFrame({"arch":["complex_derived", "complex_core", "simple"]}) 
    tfdf = pd.merge(blank_df, tfdf, how = "left").fillna(0)
    bkgd = pd.merge(blank_df, bkgd, how = "left").fillna(0)
    
    # count TFBS/blocks
    TF_arch = tfdf.loc[tfdf.arch == arch1, "enh_id"].iloc[0]
    not_TF_arch = bkgd.loc[bkgd.arch == arch1, "enh_id"].iloc[0]

    if arch2 == "bkgd":
        TF_bkgd = tfdf.loc[tfdf.arch != arch1, "enh_id"].sum()
        not_TF_bkgd = bkgd.loc[bkgd.arch != arch1, "enh_id"].sum()
    else:

        TF_bkgd= tfdf.loc[tfdf.arch == arch2, "enh_id"].iloc[0]
        not_TF_bkgd = bkgd.loc[bkgd.arch == arch2, "enh_id"].iloc[0]

    
    a, b, c, d = TF_arch, not_TF_arch, TF_bkgd, not_TF_bkgd
    
    if a > min_instances:  # don't run tests if a or c < min instances. 
        obs = np.array([[a, b], [c, d]])
        
    elif c > min_instances:
        obs = np.array([[a, b], [c, d]])
    
    else:
        obs = np.array([[0, 0], [0, 0]])

    return obs, comparison_name


def quantify_2x2(obs, comparison_name):

    if obs.sum() == 0:

        newdf = pd.DataFrame()  # return empty dataframe
    else:
        OR, P = stats.fisher_exact(obs)
        table = sm.stats.Table2x2(obs)  # get confidence interval
        odds_ci = table.oddsratio_confint()
        newdf = pd.DataFrame({"comparison_name": comparison_name,
                              "a": obs[0][0], "b": obs[0][1],
                              "c": obs[1][0], "d": obs[1][1],
                              "OR": [OR], "P": [P],
                              "ci_lower": [odds_ci[0]],
                              "ci_upper": [odds_ci[1]],
                              })
  
    return newdf


def fdr_correction(collection_dict, alpha):

    df = pd.concat(collection_dict.values())

    pvals = df["P"]

    df["reject_null"], df["FDR_P"] = statsmodels.stats.multitest.fdrcorrection(
        pvals, alpha=alpha)

    # other dataframe formatting
    df["arch"] = df["comparison_name"].apply(lambda x: x.split("-")[1])
    df["tf"] = df["comparison_name"].apply(lambda x: x.split("-")[0])
    df["log2"] = np.log2(df["OR"])

    return df


def plot_bar_tf_enrichment(df, cell_line, outf, alpha, taxon2):

    fig, ax = plt.subplots(figsize=(6, 12))
    sns.set("poster")

    x = "tf"
    y = "log2"
    hue = "arch"
    data = df.sort_values(by=y)

    sns.barplot(x=y, y=x, data=data, hue=hue, palette=DERPAL)

    ax.legend(bbox_to_anchor=(1, 1))

    if taxon2 is not None:
        label = cell_line + "_" + taxon2
    else:
        label = cell_line

    ax.set(xlabel=f"OR log2-scale\n FDR<{str(alpha)}", title=label)

    plt.savefig(outf, bbox_inches="tight")

# %%
def run_2x2(arch1, arch2, df, min_instances, alpha, taxon2):
    universes = ["TFBS", "blocks"]
    universe_dict = {}
    
    for universe in universes:
        collection_dict = {}

        for tf in df.tf.unique():

            if tf != ".":
                    # get 2x2 counts for that TF in arch1, arch2
                    obs, comparison_name = prep_2x2(tf, arch1, arch2, min_instances, df, universe)
                    print(obs, comparison_name, tf)

                    results = quantify_2x2(obs, comparison_name)
                    results["universe"] = universe

                    if results.empty is False:
                        collection_dict[comparison_name] = results

        # FDR correction
        if len(collection_dict) > 0:  # if there are any results

            results_df = fdr_correction(collection_dict, alpha)

            #df = results_df.loc[results_df.reject_null is True]

            universe_dict[universe] = results_df

        else:
            print("\nno results for comparison",
                  arch1, "v.", arch2, "in", taxon2)
    if len(universe_dict) > 0:
        results = pd.concat(universe_dict.values())  # concat two universe analyses
    else: 
        results = None
    return results

# %%
def run_analysis(cell_line, val, fantombase, encodepath, min_instances, alpha):

    print(cell_line, val)

    fantom, encode, intersection = get_paths(
        cell_line, val, fantombase, encodepath)
    
    print(fantom, encode, intersection)

    #Bed command
    bed_intersect(fantom, encode, intersection)

    #dataframe
    df = format_df(intersection)

    #get some basic info about Fantom enhancer overlap
    stats_f = os.path.join(RE_DATA, f"stats_{cell_line}.txt") # output file
    archs = ["enh", "syn"]

    for arch in archs:
        count_enhancers(df, arch, stats_f)

        # calculate enhancer TF density
        tf_density, zero = calculate_tf_density(arch, df)

        # non-zero enhancer TF density
        non_zero_tf_density = tf_density.loc[tf_density.tfoverlap_bin > 0]

        # calculate frequency of derived sequences that do not overlap TFBS
        calculate_zero_syn_freq(zero, df, arch, stats_f)

        # plot tf density data
        x, y = "arch", "tf_density"

        # get order of data depending on arch
        order_dict = {"enh":["simple", "complex"],
        "syn":["simple", "complex_core", "complex_derived"]}

        order = order_dict[arch]

        # calculate density with and without zeros
        zeros = {"w_zeros":tf_density, "nonzeros":non_zero_tf_density}

        for kw, data in zeros.items():

            outf = os.path.join(RE, f"{cell_line}_x_encode3_tf_den_{arch}_{kw}.pdf")
            listP, median = mwu(data, arch, kw, stats_f)

            # make a string of the p values for density plotting
            if len(listP) == 2:
                pStr = f"simple_v_core p = {listP[0]},  core_v_der= {listP[1]}"
            else:
                pStr = listP[0]

            plot_bar_tf_density(x, y, data, outf, order, pStr, median)

    ### TF ENRICHMENT IN ARCHITECTURE ###
    # DER V. CORE
    # DER V. BKGD

    # calculate TF enrichment in architecture/syn blocks
    arch1, arch2 = "complex_derived", "complex_core"
    der_v_core = run_2x2(arch1, arch2, df, MIN_INSTANCES, ALPHA, None)

    arch1, arch2 = "complex_derived", "bkgd"
    der_v_bkgd = run_2x2(arch1, arch2, df, MIN_INSTANCES, ALPHA, None)

    arch1, arch2 = "simple", "complex_core"
    simple_v_core = run_2x2(arch1, arch2, df, MIN_INSTANCES, ALPHA, None)

    arch1, arch2 = "simple", "bkgd"
    simple_v_bkgd = run_2x2(arch1, arch2, df, MIN_INSTANCES, ALPHA, None)

    arch1, arch2 = "simple", "complex_derived"
    simple_v_der = run_2x2(arch1, arch2, df, MIN_INSTANCES, ALPHA, None)

    arch1, arch2 = "complex_core", "bkgd"
    core_v_bkgd = run_2x2(arch1, arch2, df, MIN_INSTANCES, ALPHA, None)

    return der_v_core, der_v_bkgd, simple_v_core, simple_v_bkgd, simple_v_der, core_v_bkgd, df


def just_get_df(cell_line, val, fantombase, encodepath,):
    print(cell_line, val)
    fantom, encode, intersection = get_paths(
        cell_line, val, fantombase, encodepath)

    #Bed command
    bed_intersect(fantom, encode, intersection)

    #dataframe
    df = format_df(intersection)

    return df

# %% [markdown]
# # Run TFBS density and TFBS enrichment analysis across architectures from all ages

# %%
# %%
sample_dict = get_cell_lines()

# %%
ALPHA = 0.05
MIN_INSTANCES = 10

# %%
cell_line = "HepG2"
val = "ELS_combined_HepG2"

df_file = f"{RE_DATA}{cell_line}_df.tsv"

comp_list = ["der_v_core", "der_v_bkgd",
             "simple_v_core", "simple_v_bkgd", "simple_v_der",
             "core_v_bkgd", "df"]


if os.path.exists(df_file) is False:

    der_v_core, der_v_bkgd,  simple_v_core,\
     simple_v_bkgd, simple_v_der, core_v_bkgd, df = run_analysis(
        cell_line, val, ENHBASE, ENCODEPATH, MIN_INSTANCES, ALPHA)

    data_dict = {  # dictionary of the dataframes and odds ratio comparisons
        "der_v_core": der_v_core,
        "der_v_bkgd": der_v_bkgd,
        "simple_v_core": simple_v_core,
        "simple_v_bkgd": simple_v_bkgd,
        "simple_v_der": simple_v_der,
        "core_v_bkgd": core_v_bkgd,
        "df": df
    }



    for comp, dataframe in data_dict.items():
        print(type(dataframe))
        if dataframe.empty is False:
            outf = f"{RE_DATA}{cell_line}_{comp}.tsv"
            dataframe.to_csv(outf, sep='\t', index=False)

else:
    data_dict = {}
    for comp in comp_list:
        outf = f"{RE_DATA}{cell_line}_{comp}.tsv"
        df = pd.read_csv(outf, sep='\t')
        data_dict[comp] = df

# %% [markdown]
# # post-analysis dataframe formatting
# - add summarized mrca_2, taxon annotations
# - analyze per age enrichment based on core age?
# - summarize smaller taxa w/ larger taxa?

# %%
df = merge_syn_annot(df, False)

# %% [markdown]
# ### core age instead of syntenic age?
# asks a slightly different question -
#
# ###### are age-matched cores more enriched for TFBS than derived regions (of any age)?
#
# do the dance - add mrca_2 column, get mrca_2 core age, drop mrca_2 column,
# then add it back,
# but this time to reflect the core_age and core taxon,
#  instead of the syntenic age.

# %%
REASSIGN_DER_W_CORE_AGE = False


if REASSIGN_DER_W_CORE_AGE is True:
    df = get_core_age(df)
    df = df.drop(["mrca_2"], axis=1)
    df = merge_syn_annot(df, True)
    
else:
    df = merge_syn_annot(df, False)

# %% [markdown]
# ### reassign tiny taxa?
# - EUAR, PRIM -> BORE
# - SARG, TETR -> VERT

# %%
def reassign_small_taxons(df):
    # lump small samples with larger, older ancestors
    df.loc[df.taxon2 == "Sarcopterygian", "taxon2"] = "Vertebrata"
    df.loc[df.taxon2 == "Tetrapoda", "taxon2"] = "Vertebrata"
    df.loc[df.taxon2 == "Euarchontoglires", "taxon2"] = "Boreoeutheria"
    df.loc[df.taxon2 == "Primates", "taxon2"] = "Boreoeutheria"
    return df

# %%
REASSIGN_SMALL_TAXONS = True


if REASSIGN_SMALL_TAXONS is True:
    df = reassign_small_taxons(df)

# %% [markdown]
# # calculate TF enrichment per age.
#
# - per age, calculate mrca enrichment comparing pairwise architectures
#
#     - exclude TFs w/ <10 TFBS sites
#     - Universe: calculate TFBS-wise enrichment and summarized core-derived-wise TFBS enrichment
#     - Compare between core/derived syntenic blocks born from the same syntenic age
#
#
#     ###### this takes a long time to run (~15min)

# %% [markdown]
# ## reassign outfiles

# %%
if REASSIGN_SMALL_TAXONS is True:
    outf = f"{RE_DATA}{cell_line}_OR_per_MRCA-reassigned.tsv"
    outf = config[f"ENCODE_{cell_line}_TFBS"]['OR_reassigned']
    RE = RE + "reassigned/"
    try:
        os.mkdir(RE)
    except FileExistsError:
        pass
else:
    outf = f"{RE_DATA}{cell_line}_OR_per_MRCA.tsv"
    outf = config[f"ENCODE_{cell_line}_TFBS"]['OR']

# %%
outf
# Out:
# '/dors/capra_lab/projects/enhancer_ages/core_v_derived/results/cCRE_x_tfbs_encode3/HepG2/data/HepG2_OR_per_MRCA-reassigned.tsv'

# %%
if os.path.exists(outf) is False:  # you haven't saved the OR dataframe
    #mrca_dict = {}  # dictionary to collect data

    for TAXON2 in df.taxon2.unique():
        if TAXON2 not in mrca_dict.keys():

            print(TAXON2)
            age = df.loc[df.taxon2 == TAXON2].drop_duplicates()

            arch1, arch2 = "complex_derived", "complex_core"
            der_v_core = run_2x2(arch1, arch2, age, MIN_INSTANCES, ALPHA, TAXON2)

            arch1, arch2 = "simple", "complex_core"
            simple_v_core = run_2x2(
                arch1, arch2, age, MIN_INSTANCES, ALPHA, TAXON2)

            arch1, arch2 = "simple", "bkgd"
            simple_v_bkgd = run_2x2(
                arch1, arch2, age, MIN_INSTANCES, ALPHA, TAXON2)

            arch1, arch2 = "complex_derived", "bkgd"
            der_v_bkgd = run_2x2(arch1, arch2, age, MIN_INSTANCES, ALPHA, TAXON2)

            arch1, arch2 = "complex_core", "bkgd"
            core_v_bkgd = run_2x2(arch1, arch2, age, MIN_INSTANCES, ALPHA, TAXON2)

            arch1, arch2 = "complex_derived", "simple"
            der_v_simple = run_2x2(arch1, arch2, age, MIN_INSTANCES, ALPHA, TAXON2)

            results = [der_v_core, simple_v_core, simple_v_bkgd,
                       der_v_bkgd, core_v_bkgd, der_v_simple]

            mrca_dict[TAXON2] = results
    
    val = 0
    for mrca, dfs in mrca_dict.items():             

        for ndf in dfs:
            if ndf is not None:
                ndf["taxon2"] = mrca
                if val == 0:
                    mrca_df = ndf.copy()
                    val +=1
                else:
                    mrca_df = pd.concat([mrca_df, ndf]) 
                
    mrca_df = mrca_df.drop_duplicates()
    mrca_df["log2"] = np.log2(mrca_df.OR)

    mrca_df.to_csv(outf, sep='\t', index=None)

else:
    mrca_df = pd.read_csv(outf, sep='\t')
# Out:
# /accre/arch/easybuild/software/BinDist/Anaconda3/5.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in log2

# %% [markdown]
# # Figure 3C per age TFBS enrichment

# %%
def pivot_n_sig_annots(sorted_df, idx, col, val, sort_val):
    
        
    valDf = sorted_df.pivot(index=idx, columns=col, values=val)
    p_annot = sorted_df.pivot(index=idx, columns=col, values="reject_null")
    
    # reorder the table
    if len(list(valDf)) == 10:
        reorder_cols = ['Primate',  'Euarchontoglires', 'Boreoeutheria',
                    'Eutheria','Theria', 'Mammalia','Amniota',
                    'Tetrapoda', 'Sarcopterygian', 'Vertebrata']
        valDf = valDf[reorder_cols]
        p_annot = p_annot[reorder_cols]
    else:
        reorder_cols = ['Boreoeutheria',
                'Eutheria','Theria', 'Mammalia','Amniota',  'Vertebrata'
                ]
        valDf = valDf[reorder_cols]
        p_annot = p_annot[reorder_cols]
    
    sorted_index = valDf.sort_values(by=sort_val, ascending=False).index  # get index sorted on a value
    
    
    valDf_reindexed = valDf.reindex(sorted_index)  # reindex the p annotations
    p_annot_reindexed = p_annot.reindex(sorted_index)  # reindex the p annotations
    
    return valDf_reindexed, p_annot_reindexed

# %% [markdown]
#  # Create a custom diverging colormap

# %%
yellow_ = "#ffffcc"
light_green = "#d9f0a3"#"#ffffcc"#"#c2e699"#'#addd8e'
dark_green = "#238443"#"#41ab5d"#"#006837"#'#31a354'
offwhite =  "#fdfdfd"#"#f9f4f4"#'#ffffe4' 
y = mcolors.to_rgba(yellow_)
a = mcolors.to_rgba(light_green)
f = mcolors.to_rgba(dark_green)
o = mcolors.to_rgba(offwhite)

colors = [f, o, a, y, ]  # R -> G -> B
cmap_name = 'my_list'
CM = LinearSegmentedColormap.from_list(cmap_name, colors, N=24)

# %%
color_list = ["f1f33f", "#ffffcc", "#fdfdfd", "#d9f0a3", "#238443"] # pee yellow
color_list = ["#ebee0e", "#ffffcc", "#fdfdfd", "#d9f0a3", "#238443"] # darker pee?
color_list = ["F3F99C","#addd8e","D6EEC6","#F9FDF7",   "#ffffff", "DEF5E5", "AAE6BC","#31a354", "#316AA3"] # stem green to Kelly
# 
#color_list = ["#C0D507", "#D6ED07", "F8FDC9", "#fdfdfd", "AAE6BC", "#46905C", "#1C5E5D"] # darker pee?
color_list = color_list[::-1]

def hex_to_rgb(value):
    '''
    Converts hex to rgb colours
    value: string of 6 characters representing a hex colour.
    Returns: list length 3 of RGB values'''
    value = value.strip("#") # removes hash symbol if present
    lv = len(value)
    return tuple(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))


def rgb_to_dec(value):
    '''
    Converts rgb to decimal colours (i.e. divides each value by 256)
    value: list (length 3) of RGB values
    Returns: list (length 3) of decimal values'''
    return [v/256 for v in value]

def get_continuous_cmap(hex_list, float_list=None):
    ''' creates and returns a color map that can be used in heat map figures.
        If float_list is not provided, colour map graduates linearly between each color in hex_list.
        If float_list is provided, each color in hex_list is mapped to the respective location in float_list. 
        
        Parameters
        ----------
        hex_list: list of hex code strings
        float_list: list of floats between 0 and 1, same length as hex_list. Must start with 0 and end with 1.
        
        Returns
        ----------
        colour map'''
    rgb_list = [rgb_to_dec(hex_to_rgb(i)) for i in hex_list]
    if float_list:
        pass
    else:
        float_list = list(np.linspace(0,1,len(rgb_list)))
        
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp


CM = get_continuous_cmap(color_list, float_list=None)

def plot_heatmap(comp, df, universe):
   
        df = df.drop_duplicates()
        test = df.loc[(df.universe == universe) & (df.arch == comp)]
        
        idx = "tf"
        col = "taxon2" 
        val = "log2"
        sort_val = ["Eutheria", "Mammalia", "Amniota"]
        
        # pivot and get p values
        table, table_p = pivot_n_sig_annots(test, idx, col, val, sort_val)

        
        #table = table.dropna(thresh=2)  # drop any Na's
        table = table.replace(-np.Inf, -2)
        table = table.replace(np.Inf, 2)

        if len(table) < 25:
            figsize = (5, 10)
        else:
            figsize = (5, 35)
        
        # plot
        sns.set("notebook")
        
        fig, (ax) = plt.subplots( figsize=figsize)
        cm = sns.heatmap(table.fillna(0),
                     cmap=CM,
                     center=0,
                     square=True,
                     annot=table_p.replace({False: "", True: "*", None: "."}),
                     fmt="",
                     robust=True,
                     ax=ax
                        
                     )
        ax.set(xlabel="", ylabel="", title=f"{comp} - {universe}")
        ax.invert_xaxis()
        outf = f"{RE}{val}_{comp}_clustermap_core_mrca2-{universe}-reassigned.pdf"
        plt.savefig(outf, bbox_inches="tight", dpi=300)
        plt.show()
        plt.close()
        
        
def plot_sig_heatmap(comp, df, universe):
   
        df = df.drop_duplicates()
        
        # subset by universe and comparison
        test = df.loc[(df.universe == universe) & (df.arch == comp)]
        
        # get the significant TFs, subset dataframe to those TFs
        sig_tfs = test.loc[(test.reject_null == True), "tf"].unique()
        test = test.loc[test.tf.isin(sig_tfs)]
        
        idx = "tf"
        col = "taxon2" 
        val = "log2"
        sort_val = ["Eutheria", "Amniota", "Mammalia",]
        
        # pivot and get p values
        table, table_p = pivot_n_sig_annots(test, idx, col, val, sort_val)

        
        #table = table.dropna(thresh=2)  # drop any Na's
        table = table.replace(-np.Inf, -2)
        table = table.replace(np.Inf, 2)
        print(len(table))
        if len(table) < 60:
            figsize = (5, 15)
        else:
            figsize = (5, 35)
        
        # plot
        sns.set("notebook")
        ### prepare to plot the heatmap ###
       
 
        
        fig, (ax) = plt.subplots( figsize=figsize)
        cm = sns.heatmap(table.fillna(0),
                     cmap=RdBu,  # CM (custom color map)
                     center=0,
                     square=True,
                     annot=table_p.replace({False: "", True: "*", None: ""}),
                     fmt="",
                     robust=True,
                          vmin = -1, vmax = 1,
                     ax=ax
                     )
        ax.set(xlabel="", ylabel="", title=f"{comp} - {universe}")
        ax.invert_xaxis()
        outf = f"{RE}{val}_{comp}_clustermap_core_mrca2-{universe}_SIG_ONLY-reassigned.pdf"
        plt.savefig(outf, bbox_inches="tight", dpi=300)
        plt.show()
        plt.close()
        

## plot it!
#for comp in mrca_df.arch.unique():
#for universe in mrca_df.universe.unique():
comp = "complex_derived_v_complex_core"
universe = "TFBS"
#plot_heatmap(comp, mrca_df, universe)
plot_sig_heatmap(comp, mrca_df, universe)
# Out:
# 59

# %%
2**(-0.8), 2**(-0.4), 2**(0.4), 2**0.8, 2**1.2
# Out:
# (0.5743491774985174,
#  0.757858283255199,
#  1.3195079107728942,
#  1.7411011265922482,
#  2.2973967099940698)

# %%
mrca_dict.keys()
# Out:
# dict_keys(['Eutheria', 'Vertebrata', 'Amniota', 'Theria', 'Mammalia', 'Boreoeutheria', 'Primate', 'Homo'])

# %% [markdown]
# code in case you want to cluster the heatmap
#
#         cm = sns.clustermap(table.fillna(0),
#                             #mask=(table == 0),
#                             cmap="RdBu_r",
#                             center=0,
#                             robust=True,
#                             col_cluster=False,
#                             figsize=figsize)
#
#         cm.fig.suptitle(comp + "-" + universe)

# %% [markdown]
# # Simpson's paradox - CEBPB
#
# - per age - CEBPB is enriched in MRCA cores v. MRCA derived,
#
#     - amniota cores v. amniota derived (log2OR = -0.29, FDR_p = 0.02)
#
#     - mammalian cores v. mammalian derived (log2OR = -0.50, FDR_p = 0.04)
#
# - overall - CEBPB is enriched in derived v. cores (log2OR = 0.25, FDR_p = 1.86e-08)

# %%
CEBPB = mrca_df.loc[(mrca_df.tf == "CEBPB") & (mrca_df.universe == "TFBS") & (mrca_df.arch == "complex_derived_v_complex_core")]
CEBPB
# Out:
#              OR         P      a        b      c  ci_lower     ci_upper  \
# 39     0.966964  0.512505  799.0  39697.0  809.0  0.876039     1.067327
# 1387        NaN  1.000000    0.0      0.0  470.0  1.743609  4437.823425
# 2623   1.364059  0.151259   38.0   2023.0   55.0  0.899043     2.069596
# 3583   0.818900  0.004655  286.0  23627.0  696.0  0.712953     0.940591
# 4891   1.016992  0.847416  296.0  15607.0  413.0  0.874754     1.182358
# 6176   0.708329  0.006125   84.0   5607.0  242.0  0.551508     0.909743
# 7362   1.089506  0.531580  275.0  10517.0   81.0  0.847834     1.400065
# 8478   1.043381  0.912023   34.0   3287.0   54.0  0.677865     1.605988
# 9553   0.756046  0.541175  243.0   7071.0    1.0  0.101495     5.631838
# 10665  1.111223  0.886713   78.0   2547.0   14.0  0.624160     1.978366
#
#                                  comparison_name        d universe  \
# 39     CEBPB-complex_derived_v_complex_core-TFBS  38866.0     TFBS
# 1387   CEBPB-complex_derived_v_complex_core-TFBS  41387.0     TFBS
# 2623   CEBPB-complex_derived_v_complex_core-TFBS   3994.0     TFBS
# 3583   CEBPB-complex_derived_v_complex_core-TFBS  47085.0     TFBS
# 4891   CEBPB-complex_derived_v_complex_core-TFBS  22146.0     TFBS
# 6176   CEBPB-complex_derived_v_complex_core-TFBS  11442.0     TFBS
# 7362   CEBPB-complex_derived_v_complex_core-TFBS   3375.0     TFBS
# 8478   CEBPB-complex_derived_v_complex_core-TFBS   5447.0     TFBS
# 9553   CEBPB-complex_derived_v_complex_core-TFBS     22.0     TFBS
# 10665  CEBPB-complex_derived_v_complex_core-TFBS    508.0     TFBS
#
#        reject_null     FDR_P                            arch     tf      log2  \
# 39           False  0.633095  complex_derived_v_complex_core  CEBPB -0.048466
# 1387         False  1.000000  complex_derived_v_complex_core  CEBPB       NaN
# 2623         False  0.453778  complex_derived_v_complex_core  CEBPB  0.447906
# 3583          True  0.023064  complex_derived_v_complex_core  CEBPB -0.288241
# 4891         False  0.937567  complex_derived_v_complex_core  CEBPB  0.024308
# 6176          True  0.041478  complex_derived_v_complex_core  CEBPB -0.497508
# 7362         False  1.000000  complex_derived_v_complex_core  CEBPB  0.123674
# 8478         False  1.000000  complex_derived_v_complex_core  CEBPB  0.061266
# 9553         False  1.000000  complex_derived_v_complex_core  CEBPB -0.403454
# 10665        False  1.000000  complex_derived_v_complex_core  CEBPB  0.152149
#
#                  taxon2
# 39             Eutheria
# 1387         Vertebrata
# 2623     Sarcopterygian
# 3583            Amniota
# 4891             Theria
# 6176           Mammalia
# 7362      Boreoeutheria
# 8478          Tetrapoda
# 9553            Primate
# 10665  Euarchontoglires

# %%
CEBPB['a'].sum(), CEBPB['b'].sum(), CEBPB['c'].sum(), CEBPB['d'].sum()
# Out:
# (2133.0, 109983.0, 2835.0, 174272.0)

# %%
dc = data_dict["der_v_core"]
dc = dc.loc[dc.universe == "TFBS"]

dc.loc[(dc.tf == "CEBPB") & (dc.arch == "complex_derived_v_complex_core")]
# Out:
#           OR             P     a       b     c  ci_lower  ci_upper  \
# 36  1.192653  1.302181e-09  2135  110042  2835  1.126947  1.262189
#
#                               comparison_name       d universe  reject_null  \
# 36  CEBPB-complex_derived_v_complex_core-TFBS  174272     TFBS         True
#
#            FDR_P                            arch     tf      log2
# 36  1.855608e-08  complex_derived_v_complex_core  CEBPB  0.254174

# %% [markdown]
# # All core v. der TFBS enrichment
# ## does not consider core v. der age

# %%
universes = ["TFBS", "blocks"]
for universe in universes:
    dc = data_dict["der_v_core"]
    dc = dc.loc[dc.universe == universe]
    dc["dummy"] = 0
    dc.loc[dc.tf == "FOXA1"]

    dcp = dc.pivot(index='tf', values="log2", columns="dummy")
    dcp_p = dc.pivot(index='tf', values="reject_null", columns="dummy")


    sorted_index = dcp.sort_values(by=0, ascending=False).index
    dcp_p = dcp_p.reindex(sorted_index)

    """
    Reset index to split dataframe
    split dataframes into core and derived
    reindex core and derived significant arrays by new dataframes
    reset TF as the index
    """
    % matplotlib inline

    d = dcp.reset_index()  # reindex
    dp = dcp_p.reset_index()

    # split into core and der
    core_only, der_only = d.loc[d[0] < 0], d.loc[d[0] >= 0]

    # sort values from highest to lowest OR
    core_only, der_only = core_only.sort_values(
        by=0), der_only.sort_values(by=0, ascending=False)

    # get sorted core index, reindex significance array
    coresorted_index = core_only.sort_values(by=0)["tf"].index
    dcp_pcore = dp.reindex(coresorted_index)

    # get sorted derived index, reindex significance array
    dsorted_index = der_only.sort_values(by=0, ascending=False)["tf"].index
    dcp_pder = dp.reindex(dsorted_index)

    # reset index as TF for all dataframes
    core_only = core_only.set_index("tf")
    dcp_pcore = dcp_pcore.set_index("tf")

    der_only = der_only.set_index("tf")
    dcp_pder = dcp_pder.set_index("tf")
    #%%

    fig, (ax, ax2) = plt.subplots(ncols=2, figsize=(8, 20))
    cm = sns.heatmap(core_only,
                     cmap="RdBu_r",
                     center=0,
                     square=True,
                     annot=dcp_pcore.replace({False: "", True: "*"}),
                     fmt="",
                     robust=True,
                     ax=ax
                     )
    ax.set(xlabel="", ylabel="", title="core")
    cm.set_xlabel(""), cm.set_xticklabels("")

    ax2 = sns.heatmap(der_only,
                      cmap="RdBu_r",
                      center=0,
                      square=True,
                      annot=dcp_pder.replace({False: "", True: "*"}),
                      fmt="",
                      robust=True,
                      ax=ax2)
    ax2.set(xlabel="", ylabel="", title="derived")
    ax2.set_xticklabels("")
    outf = os.path.join(RE, f"Figure2C_core_derived_{universe}.pdf")
    plt.savefig(outf, bbox_inches="tight")
    plt.show()

# %% [markdown]
# # plot syntenic TFBS density as a sanity check.

# %%
#%%
synden = data_dict["tf_density_syn"]
synden.head()
test = data_dict["df"]
# add core mrca age
test = pd.merge(test, syn[["mrca", "mrca_2"]])
test = get_core_age(test)
# add age info to tf density dataframe
synden = pd.merge(
    synden, test[["syn_id", "core_mrca_2"]], left_on='id', right_on="syn_id")

#%% plot
x, y = "core_mrca_2", 'tf_density'
hue = "arch"
hue_order = ["simple", "complex_core", "complex_derived"]
xlabs = ["Homo", "Prim", "Euar", "Bore", "Euth",
         "Ther", "Mam", "Amni", "Tetr", "Sarg", "Vert"]
fig, ax = plt.subplots(figsize=(6, 6))
sns.barplot(x, y, data=synden, hue=hue, palette=PAL, hue_order=hue_order)
ax.legend(bbox_to_anchor=(1, 1))
ax.set_xticklabels(xlabs, rotation=90)

outf = f"{RE}{cell_line}_tfbs_density_core_mrca_2.pdf"
outf
plt.savefig(outf, bbox_inches="tight")

#%%

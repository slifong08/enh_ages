# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("biomaRt")
# Out:
# Error in contrib.url(repos, type): trying to use CRAN without setting a mirror
# Error in loadNamespace(name): there is no package called ‘BiocManager’

# %%
installed.packages()
# Out:
#               Package
# AnnotationDbi "AnnotationDbi"
# base          "base"
# base64enc     "base64enc"
# Biobase       "Biobase"
# BiocGenerics  "BiocGenerics"
# BiocInstaller "BiocInstaller"
# biomaRt       "biomaRt"
# bitops        "bitops"
# boot          "boot"
# class         "class"
# cluster       "cluster"
# codetools     "codetools"
# compiler      "compiler"
# datasets      "datasets"
# DBI           "DBI"
# digest        "digest"
# evaluate      "evaluate"
# foreign       "foreign"
# generics      "generics"
# graphics      "graphics"
# grDevices     "grDevices"
# grid          "grid"
# IRanges       "IRanges"
# IRdisplay     "IRdisplay"
# IRkernel      "IRkernel"
# jsonlite      "jsonlite"
# KernSmooth    "KernSmooth"
# lattice       "lattice"
# magrittr      "magrittr"
# MASS          "MASS"
# Matrix        "Matrix"
# methods       "methods"
# mgcv          "mgcv"
# nlme          "nlme"
# nnet          "nnet"
# parallel      "parallel"
# pkgconfig     "pkgconfig"
# R6            "R6"
# RCurl         "RCurl"
# repr          "repr"
# rpart         "rpart"
# RSQLite       "RSQLite"
# rzmq          "rzmq"
# S4Vectors     "S4Vectors"
# spatial       "spatial"
# splines       "splines"
# stats         "stats"
# stats4        "stats4"
# stringi       "stringi"
# stringr       "stringr"
# survival      "survival"
# tcltk         "tcltk"
# tools         "tools"
# utils         "utils"
# uuid          "uuid"
# XML           "XML"
#               LibPath                                              Version
# AnnotationDbi "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.32.3"
# base          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# base64enc     "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.1-3"
# Biobase       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.32.0"
# BiocGenerics  "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.18.0"
# BiocInstaller "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.20.3"
# biomaRt       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.26.1"
# bitops        "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.0-6"
# boot          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.3-17"
# class         "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "7.3-14"
# cluster       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.0.3"
# codetools     "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.2-14"
# compiler      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# datasets      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# DBI           "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.3.1"
# digest        "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.6.9"
# evaluate      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.8"
# foreign       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.8-66"
# generics      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.1.0"
# graphics      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# grDevices     "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# grid          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# IRanges       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.4.8"
# IRdisplay     "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.3"
# IRkernel      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.5"
# jsonlite      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.9.19"
# KernSmooth    "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.23-15"
# lattice       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.20-33"
# magrittr      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.5"
# MASS          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "7.3-45"
# Matrix        "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.2-2"
# methods       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# mgcv          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.8-9"
# nlme          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.1-122"
# nnet          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "7.3-11"
# parallel      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# pkgconfig     "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.0.3"
# R6            "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.5.0"
# RCurl         "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.95-4.7"
# repr          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.3"
# rpart         "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "4.1-10"
# RSQLite       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.0.0"
# rzmq          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.7.7"
# S4Vectors     "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.8.11"
# spatial       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "7.3-11"
# splines       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# stats         "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# stats4        "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# stringi       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.0-1"
# stringr       "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "1.0.0"
# survival      "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "2.38-3"
# tcltk         "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# tools         "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# utils         "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.2.2"
# uuid          "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "0.1-2"
# XML           "/data1/home/fongsl/.conda/envs/sfenv/lib/R/library" "3.98-1.3"
#               Priority
# AnnotationDbi NA
# base          "base"
# base64enc     NA
# Biobase       NA
# BiocGenerics  NA
# BiocInstaller NA
# biomaRt       NA
# bitops        NA
# boot          NA
# class         NA
# cluster       NA
# codetools     NA
# compiler      "base"
# datasets      "base"
# DBI           NA
# digest        NA
# evaluate      NA
# foreign       NA
# generics      NA
# graphics      "base"
# grDevices     "base"
# grid          "base"
# IRanges       NA
# IRdisplay     NA
# IRkernel      NA
# jsonlite      NA
# KernSmooth    NA
# lattice       NA
# magrittr      NA
# MASS          NA
# Matrix        NA
# methods       "base"
# mgcv          NA
# nlme          NA
# nnet          NA
# parallel      "base"
# pkgconfig     NA
# R6            NA
# RCurl         NA
# repr          NA
# rpart         NA
# RSQLite       NA
# rzmq          NA
# S4Vectors     NA
# spatial       NA
# splines       "base"
# stats         "base"
# stats4        "base"
# stringi       NA
# stringr       NA
# survival      NA
# tcltk         "base"
# tools         "base"
# utils         "base"
# uuid          NA
# XML           NA
#               Depends
# AnnotationDbi "R (>= 2.7.0), methods, utils, stats4, BiocGenerics (>=\n0.15.10), Biobase (>= 1.17.0), IRanges"
# base          NA
# base64enc     "R (>= 2.9.0)"
# Biobase       "R (>= 2.10), BiocGenerics (>= 0.3.2), utils"
# BiocGenerics  "methods, utils, graphics, stats, parallel"
# BiocInstaller "R (>= 3.2.0)"
# biomaRt       "methods"
# bitops        NA
# boot          "R (>= 3.0.0), graphics, stats"
# class         "R (>= 3.0.0), stats, utils"
# cluster       "R (>= 2.15.0), utils"
# codetools     "R (>= 2.1)"
# compiler      NA
# datasets      NA
# DBI           "R (>= 2.15.0), methods"
# digest        "R (>= 2.4.1)"
# evaluate      "R (>= 3.0.2)"
# foreign       "R (>= 3.0.0)"
# generics      "R (>= 3.1)"
# graphics      NA
# grDevices     NA
# grid          NA
# IRanges       "R (>= 3.1.0), methods, utils, stats, BiocGenerics (>=\n0.15.10), S4Vectors (>= 0.8.4)"
# IRdisplay     "\nR (>= 3.0.1)"
# IRkernel      "\nR (>= 3.0.1)"
# jsonlite      "methods"
# KernSmooth    "R (>= 2.5.0), stats"
# lattice       "R (>= 3.0.0)"
# magrittr      NA
# MASS          "R (>= 3.1.0), grDevices, graphics, stats, utils"
# Matrix        "R (>= 3.0.1)"
# methods       NA
# mgcv          "R (>= 2.14.0), nlme (>= 3.1-64)"
# nlme          "graphics, stats, R (>= 3.0.0)"
# nnet          "R (>= 2.14.0), stats, utils"
# parallel      NA
# pkgconfig     NA
# R6            "R (>= 3.0)"
# RCurl         "R (>= 3.0.0), methods, bitops"
# repr          "\nR (>= 3.0.1)"
# rpart         "R (>= 2.15.0), graphics, stats, grDevices"
# RSQLite       "R (>= 2.10.0), DBI (>= 0.3.1), methods"
# rzmq          NA
# S4Vectors     "R (>= 3.1.0), methods, utils, stats, stats4, BiocGenerics (>=\n0.15.10)"
# spatial       "R (>= 3.0.0), graphics, stats, utils"
# splines       NA
# stats         NA
# stats4        NA
# stringi       "R (>= 2.13.1)"
# stringr       "R (>= 2.14)"
# survival      "R (>= 2.13.0), graphics, stats"
# tcltk         NA
# tools         NA
# utils         NA
# uuid          "R (>= 2.9.0)"
# XML           "R (>= 2.13.0), methods, utils"
#               Imports
# AnnotationDbi "methods, utils, DBI, RSQLite, stats4, BiocGenerics, Biobase,\nS4Vectors, IRanges"
# base          NA
# base64enc     NA
# Biobase       "methods"
# BiocGenerics  "methods, utils, graphics, stats, parallel"
# BiocInstaller NA
# biomaRt       "utils, XML, RCurl, AnnotationDbi"
# bitops        NA
# boot          NA
# class         "MASS"
# cluster       "graphics, grDevices, stats"
# codetools     NA
# compiler      NA
# datasets      NA
# DBI           NA
# digest        NA
# evaluate      "methods, stringr (>= 0.6.2)"
# foreign       "methods, utils, stats"
# generics      "methods"
# graphics      "grDevices"
# grDevices     NA
# grid          "grDevices"
# IRanges       "stats4"
# IRdisplay     "\nrepr,\nbase64enc"
# IRkernel      "\nrepr,\nmethods,\nevaluate (>= 0.5.4),\nIRdisplay,\nrzmq (>= 0.7.0),\njsonlite (>= 0.9.6),\nuuid,\ndigest"
# jsonlite      NA
# KernSmooth    NA
# lattice       "grid, grDevices, graphics, stats, utils"
# magrittr      NA
# MASS          "methods"
# Matrix        "methods, graphics, grid, stats, utils, lattice"
# methods       "utils"
# mgcv          "methods, stats, graphics, Matrix"
# nlme          "lattice"
# nnet          NA
# parallel      "tools"
# pkgconfig     "utils"
# R6            NA
# RCurl         NA
# repr          NA
# rpart         NA
# RSQLite       NA
# rzmq          NA
# S4Vectors     "methods, utils, stats, stats4, BiocGenerics"
# spatial       NA
# splines       "graphics, stats"
# stats         NA
# stats4        "graphics, methods, stats"
# stringi       "tools, utils, stats"
# stringr       "stringi (>= 0.4.1), magrittr"
# survival      "splines, methods"
# tcltk         "utils"
# tools         NA
# utils         NA
# uuid          NA
# XML           NA
#               LinkingTo
# AnnotationDbi NA
# base          NA
# base64enc     NA
# Biobase       NA
# BiocGenerics  NA
# BiocInstaller NA
# biomaRt       NA
# bitops        NA
# boot          NA
# class         NA
# cluster       NA
# codetools     NA
# compiler      NA
# datasets      NA
# DBI           NA
# digest        NA
# evaluate      NA
# foreign       NA
# generics      NA
# graphics      NA
# grDevices     NA
# grid          NA
# IRanges       "S4Vectors"
# IRdisplay     NA
# IRkernel      NA
# jsonlite      NA
# KernSmooth    NA
# lattice       NA
# magrittr      NA
# MASS          NA
# Matrix        NA
# methods       NA
# mgcv          NA
# nlme          NA
# nnet          NA
# parallel      NA
# pkgconfig     NA
# R6            NA
# RCurl         NA
# repr          NA
# rpart         NA
# RSQLite       NA
# rzmq          NA
# S4Vectors     NA
# spatial       NA
# splines       NA
# stats         NA
# stats4        NA
# stringi       NA
# stringr       NA
# survival      NA
# tcltk         NA
# tools         NA
# utils         NA
# uuid          NA
# XML           NA
#               Suggests
# AnnotationDbi "DBI (>= 0.2-4), RSQLite (>= 0.6-4), hgu95av2.db, GO.db,\norg.Sc.sgd.db, org.At.tair.db, KEGG.db, RUnit,\nTxDb.Hsapiens.UCSC.hg19.knownGene, hom.Hs.inp.db, org.Hs.eg.db,\nreactome.db, AnnotationForge, graph, BiocStyle, knitr"
# base          NA
# base64enc     NA
# Biobase       "tools, tkWidgets, ALL, RUnit, golubEsets"
# BiocGenerics  "Biobase, S4Vectors, IRanges, GenomicRanges, AnnotationDbi,\noligoClasses, oligo, affyPLM, flowClust, affy, DESeq2, MSnbase,\nannotate, RUnit"
# BiocInstaller "devtools, RUnit, BiocGenerics"
# biomaRt       "annotate"
# bitops        NA
# boot          "MASS, survival"
# class         NA
# cluster       "MASS"
# codetools     NA
# compiler      NA
# datasets      NA
# DBI           "testthat, RSQLite"
# digest        "knitr, rmarkdown"
# evaluate      "testthat, lattice, ggplot2"
# foreign       NA
# generics      "covr, pkgload, testthat, tibble"
# graphics      NA
# grDevices     NA
# grid          "lattice"
# IRanges       "XVector, GenomicRanges, BSgenome.Celegans.UCSC.ce2, RUnit"
# IRdisplay     NA
# IRkernel      NA
# jsonlite      "curl (>= 0.5), plyr, testthat, knitr, rmarkdown, R.rsp"
# KernSmooth    "MASS"
# lattice       "KernSmooth, MASS"
# magrittr      "testthat, knitr"
# MASS          "lattice, nlme, nnet, survival"
# Matrix        "expm, MASS"
# methods       NA
# mgcv          "splines, parallel, survival, MASS"
# nlme          "Hmisc, MASS"
# nnet          "MASS"
# parallel      NA
# pkgconfig     "covr, testthat, disposables (>= 1.0.3)"
# R6            "knitr, microbenchmark, pryr, testthat, ggplot2, scales"
# RCurl         "Rcompression, XML"
# repr          "\nhighr"
# rpart         "survival"
# RSQLite       "testthat"
# rzmq          NA
# S4Vectors     "IRanges, RUnit"
# spatial       "MASS"
# splines       NA
# stats         NA
# stats4        NA
# stringi       NA
# stringr       "testthat, knitr"
# survival      "cmprsk"
# tcltk         NA
# tools         "XML"
# utils         NA
# uuid          NA
# XML           "bitops, RCurl"
#               Enhances
# AnnotationDbi NA
# base          NA
# base64enc     "png"
# Biobase       NA
# BiocGenerics  NA
# BiocInstaller NA
# biomaRt       NA
# bitops        NA
# boot          NA
# class         NA
# cluster       NA
# codetools     NA
# compiler      NA
# datasets      NA
# DBI           NA
# digest        NA
# evaluate      NA
# foreign       NA
# generics      NA
# graphics      NA
# grDevices     NA
# grid          NA
# IRanges       NA
# IRdisplay     NA
# IRkernel      NA
# jsonlite      NA
# KernSmooth    NA
# lattice       "chron"
# magrittr      NA
# MASS          NA
# Matrix        "MatrixModels, graph, SparseM, sfsmisc"
# methods       NA
# mgcv          NA
# nlme          NA
# nnet          NA
# parallel      "snow, nws, Rmpi"
# pkgconfig     NA
# R6            NA
# RCurl         NA
# repr          NA
# rpart         NA
# RSQLite       NA
# rzmq          NA
# S4Vectors     NA
# spatial       NA
# splines       NA
# stats         NA
# stats4        NA
# stringi       NA
# stringr       NA
# survival      NA
# tcltk         NA
# tools         NA
# utils         NA
# uuid          NA
# XML           NA
#               License                       License_is_FOSS
# AnnotationDbi "Artistic-2.0"                NA
# base          "Part of R 3.2.2"             NA
# base64enc     "GPL-2 | GPL-3"               NA
# Biobase       "Artistic-2.0"                NA
# BiocGenerics  "Artistic-2.0"                NA
# BiocInstaller "Artistic-2.0"                NA
# biomaRt       "Artistic-2.0"                NA
# bitops        "GPL (>= 2)"                  NA
# boot          "Unlimited"                   NA
# class         "GPL-2 | GPL-3"               NA
# cluster       "GPL (>= 2)"                  NA
# codetools     "GPL"                         NA
# compiler      "Part of R 3.2.2"             NA
# datasets      "Part of R 3.2.2"             NA
# DBI           "LGPL (>= 2)"                 NA
# digest        "GPL-2"                       NA
# evaluate      "MIT + file LICENSE"          NA
# foreign       "GPL (>= 2)"                  NA
# generics      "MIT + file LICENSE"          NA
# graphics      "Part of R 3.2.2"             NA
# grDevices     "Part of R 3.2.2"             NA
# grid          "Part of R 3.2.2"             NA
# IRanges       "Artistic-2.0"                NA
# IRdisplay     "MIT + file LICENSE"          NA
# IRkernel      "MIT + file LICENSE"          NA
# jsonlite      "MIT + file LICENSE"          NA
# KernSmooth    "Unlimited"                   NA
# lattice       "GPL (>= 2)"                  NA
# magrittr      "MIT + file LICENSE"          NA
# MASS          "GPL-2 | GPL-3"               NA
# Matrix        "GPL (>= 2)"                  NA
# methods       "Part of R 3.2.2"             NA
# mgcv          "GPL (>= 2)"                  NA
# nlme          "GPL (>= 2)"                  NA
# nnet          "GPL-2 | GPL-3"               NA
# parallel      "Part of R 3.2.2"             NA
# pkgconfig     "MIT + file LICENSE"          NA
# R6            "MIT + file LICENSE"          NA
# RCurl         "BSD"                         NA
# repr          "GPL-3"                       NA
# rpart         "GPL-2 | GPL-3"               NA
# RSQLite       "LGPL (>= 2)"                 NA
# rzmq          "GPL-3"                       NA
# S4Vectors     "Artistic-2.0"                NA
# spatial       "GPL-2 | GPL-3"               NA
# splines       "Part of R 3.2.2"             NA
# stats         "Part of R 3.2.2"             NA
# stats4        "Part of R 3.2.2"             NA
# stringi       "file LICENSE"                "yes"
# stringr       "GPL-2"                       NA
# survival      "LGPL (>= 2)"                 NA
# tcltk         "Part of R 3.2.2"             NA
# tools         "Part of R 3.2.2"             NA
# utils         "Part of R 3.2.2"             NA
# uuid          "MIT + file LICENSE"          NA
# XML           "BSD_2_clause + file LICENSE" NA
#               License_restricts_use OS_type MD5sum NeedsCompilation Built
# AnnotationDbi NA                    NA      NA     "no"             "3.2.2"
# base          NA                    NA      NA     NA               "3.2.2"
# base64enc     NA                    NA      NA     "yes"            "3.2.2"
# Biobase       NA                    NA      NA     NA               "3.2.2"
# BiocGenerics  NA                    NA      NA     NA               "3.2.2"
# BiocInstaller NA                    NA      NA     "no"             "3.2.2"
# biomaRt       NA                    NA      NA     "no"             "3.2.2"
# bitops        NA                    NA      NA     "yes"            "3.2.2"
# boot          NA                    NA      NA     "no"             "3.2.2"
# class         NA                    NA      NA     "yes"            "3.2.1"
# cluster       NA                    NA      NA     "yes"            "3.2.2"
# codetools     NA                    NA      NA     "no"             "3.2.2"
# compiler      NA                    NA      NA     NA               "3.2.2"
# datasets      NA                    NA      NA     NA               "3.2.2"
# DBI           NA                    NA      NA     "no"             "3.2.2"
# digest        NA                    NA      NA     "yes"            "3.2.2"
# evaluate      NA                    NA      NA     "no"             "3.2.2"
# foreign       NA                    NA      NA     "yes"            "3.2.2"
# generics      NA                    NA      NA     "no"             "3.5.0"
# graphics      NA                    NA      NA     NA               "3.2.2"
# grDevices     NA                    NA      NA     NA               "3.2.2"
# grid          NA                    NA      NA     NA               "3.2.2"
# IRanges       NA                    NA      NA     "yes"            "3.2.2"
# IRdisplay     NA                    NA      NA     NA               "3.2.2"
# IRkernel      NA                    NA      NA     NA               "3.2.2"
# jsonlite      NA                    NA      NA     "yes"            "3.2.2"
# KernSmooth    NA                    NA      NA     "yes"            "3.2.2"
# lattice       NA                    NA      NA     "yes"            "3.2.2"
# magrittr      NA                    NA      NA     "no"             "3.2.2"
# MASS          NA                    NA      NA     "yes"            "3.2.2"
# Matrix        NA                    NA      NA     "yes"            "3.2.1"
# methods       NA                    NA      NA     NA               "3.2.2"
# mgcv          NA                    NA      NA     "yes"            "3.2.2"
# nlme          NA                    NA      NA     "yes"            "3.2.1"
# nnet          NA                    NA      NA     "yes"            "3.2.2"
# parallel      NA                    NA      NA     NA               "3.2.2"
# pkgconfig     NA                    NA      NA     "no"             "3.5.0"
# R6            NA                    NA      NA     "no"             "3.5.0"
# RCurl         NA                    NA      NA     "yes"            "3.2.2"
# repr          NA                    NA      NA     NA               "3.2.2"
# rpart         NA                    NA      NA     "yes"            "3.2.2"
# RSQLite       NA                    NA      NA     "yes"            "3.2.2"
# rzmq          NA                    NA      NA     "yes"            "3.2.2"
# S4Vectors     NA                    NA      NA     "yes"            "3.2.2"
# spatial       NA                    NA      NA     "yes"            "3.2.2"
# splines       NA                    NA      NA     NA               "3.2.2"
# stats         NA                    NA      NA     NA               "3.2.2"
# stats4        NA                    NA      NA     NA               "3.2.2"
# stringi       NA                    NA      NA     "yes"            "3.2.2"
# stringr       NA                    NA      NA     "no"             "3.2.2"
# survival      NA                    NA      NA     "yes"            "3.2.2"
# tcltk         NA                    NA      NA     NA               "3.2.2"
# tools         NA                    NA      NA     NA               "3.2.2"
# utils         NA                    NA      NA     NA               "3.2.2"
# uuid          NA                    NA      NA     "yes"            "3.2.2"
# XML           NA                    NA      NA     "yes"            "3.2.2"

# %%
library('biomaRt')

# %%
listEnsembl()
# Out:
#              biomart                version
# 1            ensembl      Ensembl Genes 104
# 2 ENSEMBL_MART_MOUSE      Mouse strains 104
# 3                snp  Ensembl Variation 104
# 4         regulation Ensembl Regulation 104

# %%
ensembl <- useEnsembl(biomart = "ensembl", mirror = "uswest")

# %%
datasets <- listDatasets(ensembl)
head(datasets)
# Out:
# Warning message:
# In scan(file, what, nmax, sep, dec, quote, skip, nlines, na.strings, : EOF within quoted string
#                   dataset                                      description
# 1    bbbison_gene_ensembl              American bison genes (Bison_UMD1.0)
# 2  smerianae_gene_ensembl Argentine black and white tegu genes (HLtupMer3)
# 3     dordii_gene_ensembl                    Kangaroo rat genes (Dord_2.0)
# 4   cjacchus_gene_ensembl                     Marmoset genes (ASM275486v1)
# 5 gaculeatus_gene_ensembl                     Stickleback genes (BROAD S1)
# 6       pleo_gene_ensembl                           Lion genes (PanLeo1.0)
#        version
# 1 Bison_UMD1.0
# 2    HLtupMer3
# 3     Dord_2.0
# 4  ASM275486v1
# 5     BROAD S1
# 6    PanLeo1.0

# %%
ensembl <- useDataset(dataset = "hsapiens_gene_ensembl", mart = ensembl)
# Out:
# Warning message:
# In scan(file, what, nmax, sep, dec, quote, skip, nlines, na.strings, : EOF within quoted string

# %%
attributes = listAttributes(ensembl)
attributes[1:5,]
# Out:
#                            name                  description
# 1               ensembl_gene_id               Gene stable ID
# 2       ensembl_gene_id_version       Gene stable ID version
# 3         ensembl_transcript_id         Transcript stable ID
# 4 ensembl_transcript_id_version Transcript stable ID version
# 5            ensembl_peptide_id            Protein stable ID

# %%
affyids <- c("ENST00000379370.7")
getBM(attributes = c('entrezgene_id', 'ensembl_transcript_id'),
      values = affyids, 
      mart = ensembl)
